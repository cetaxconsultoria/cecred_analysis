# %% [markdown]
# # Recommending products to existing users
#
# Based on other users and items
#
# First we need to create a version of our data matrix that allows us to work with the data
#
# We do it by selecting only the VL_ columns and considering each row a user (the indexes, their IDs)
#
# **Note: this is just a prototype. Real recommender systems need much more data than simply user preferences.**
#
# Thus, this system is prone to suffer from cold starts with both new users and products.
#
# It also does not scale, does not learn from bias and does not take serial data.

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import numpy as np

from reco.recommender import SVDRecommender

# %% [markdown]
# First we download the data and set the indexes to some useful names

# %%
raw_data = pd.read_csv("../../data/datasets/raw.csv", sep="|")
names = pd.read_csv("../../data/datasets/names.csv")
raw_data = raw_data.set_index(names['name'])
data = raw_data
# Out:
# /Users/Maronato/pyenvs/_Users_Maronato_Documents_Cetax_cecred/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data[list(filter(lambda x: "VL" in x, data.columns.values))].columns.values
# Out:
# array(['DSESTCVL', 'VL_RENDA_FATANUAL', 'VL_RENDA_PFPJ', 'VL_DOMICBANC',
#        'VL_PLANOCOTAS', 'VL_PLANOPOUPPROG', 'VL_LMTCARTAOCREDITO',
#        'VL_LMTCHESPECIAL', 'VL_EMP_FINAN', 'VL_APLICACAO',
#        'VL_COTASCAPITAL', 'VL_POUPPROG', 'VL_CONSORCIO', 'VL_RECEB_FOLHA',
#        'VL_LMTTRANSACAO', 'VL_LMTDESCTTIT', 'VL_LMTDESCTCHEQ',
#        'VL_COBBANC', 'VL_SEG_VIDA', 'VL_SEG_RES', 'VL_SEG_AUTO',
#        'VL_CONV_FOLHA_PAGTO', 'VL_DEBITOAUT'], dtype=object)

# %% [markdown]
# Now we select the items columns and set zeros as nan

# %%
products = list(filter(lambda x: x.startswith("VL"), data.columns.values))
data = data[products]
data = data.fillna(0)
for column in data.columns.values:
    try:
        data[column] = data[column].str.replace(',', '')
    except:
        pass
    data[column] = pd.to_numeric(data[column], errors='coerce')

data = data.replace(0, np.NaN)

# %% [markdown]
# Lets see our new dataset

# %%
data
# Out:
#                       VL_RENDA_FATANUAL  VL_RENDA_PFPJ  VL_DOMICBANC  \
# name
# Eric Modafferi             1.745000e+04         2980.0           NaN
# Jay Robinson               2.000000e+04        51307.0           NaN
# William Dickhoff           1.933774e+07       178111.0           NaN
# Ernesto Jackson            6.501000e+04        54175.0           NaN
# Jack Barnett               3.752502e+07      6359236.0           NaN
# Jamie Hamilton             2.919665e+06       423845.0           NaN
# Emelina Harrell            2.547475e+07        23940.0           NaN
# Eric Moore                 1.000000e+00         3800.0           NaN
# Eric Fitzgerald            1.765406e+06        13404.0           NaN
# Gloria Taylor              1.200000e+05      1401543.0           NaN
# Betty Levy                 2.110206e+07       245516.0        9595.0
# Genevieve Brown            4.702000e+05        45300.0           NaN
# Rodney Montague            3.380000e+05      2816667.0       87031.0
# David Mcguffee             3.655506e+07     37716476.0           NaN
# Gertrude Freer             6.318642e+07       689204.0      216824.0
# Abraham Gaytan             1.200382e+08     10003181.0           NaN
# Cynthia Curley             1.000000e+00         2000.0           NaN
# Blythe Konowal             1.740350e+05        59950.0           NaN
# Kenneth Drayton            3.982856e+07     15853476.0           NaN
# Ellen Simmons              4.026561e+07      3355467.0           NaN
# Sandra Cleare              4.865640e+05        40547.0           NaN
# Christine Newton           2.535310e+05        32367.0           NaN
# Michael Mcglothin          1.500000e+04         1250.0           NaN
# Anthony Wall               2.997000e+03         2997.0           NaN
# Maurice Morton             8.298500e+04         9720.0           NaN
# Edmond Roach               1.000000e+03         4600.0           NaN
# Robyn Davis                1.000000e+00         5000.0           NaN
# Andrew Hookano             4.630743e+08      5623569.0           NaN
# Hollis Kellam              8.441157e+07     10254727.0           NaN
# Brian Rodney               4.982930e+07      6295544.0           NaN
# ...                                 ...            ...           ...
# Christopher Mcanulty       4.125470e+05      3437892.0           NaN
# Will Ahmad                 9.185130e+07     76542751.0           NaN
# Thomas Yanko               7.953600e+04     17539763.0           NaN
# Steven Holmes              4.301900e+04      1852545.0     1227925.0
# Helen Lowell               3.319400e+04         3193.0        3069.0
# Angela Daley               1.997780e+05         4073.0           NaN
# Joan Ferrell               5.401820e+05        21974.0           NaN
# Mark Irvin                 1.000000e+00         5503.0           NaN
# Ann Bostick                6.461168e+07      5628377.0           NaN
# Ricky Young                1.718175e+06       939125.0           NaN
# Melissa Sodhi              8.090700e+04       674225.0           NaN
# Jill Riordan               2.900000e+04        29000.0           NaN
# Kelvin Hankins             1.000000e+00            8.0           NaN
# Mary Houis                 6.073580e+05        50970.0           NaN
# Rosie Collins              9.351358e+09    779279834.0           NaN
# David Fritcher             6.231250e+05       325075.0           NaN
# Sue Moore                  1.703246e+07      1429605.0           NaN
# Renata Brown               1.000000e+00       169616.0       35562.0
# Kathy Adams                2.204300e+05        19950.0           NaN
# Shannon Otsu               1.000000e+00      1452542.0           NaN
# Timothy Garner             6.105389e+06        90195.0           NaN
# Vanessa Geiger             1.000000e+00         5500.0      401101.0
# Janet Franco               1.497379e+07      4967253.0           NaN
# Kenneth Vaccaro            5.769938e+08     61470409.0           NaN
# Maria Skeesick             2.021319e+07      1684433.0           NaN
# Ricky Kocher               1.111450e+05      1106735.0           NaN
# Ty Taylor                  3.955677e+06        33094.0           NaN
# Marietta Merrigan          7.815517e+08     75133062.0           NaN
# Shawnee Johnson            8.984311e+06      1380713.0           NaN
# Albert Flom                3.982543e+07       710028.0           NaN
#
#                       VL_PLANOCOTAS  VL_PLANOPOUPPROG  VL_LMTCARTAOCREDITO  \
# name
# Eric Modafferi                 10.0               NaN                  NaN
# Jay Robinson                   20.0              25.0                  1.0
# William Dickhoff               50.0               NaN                  NaN
# Ernesto Jackson                25.0               NaN               2000.0
# Jack Barnett                   55.0               NaN               5000.0
# Jamie Hamilton               5437.0               NaN               2000.0
# Emelina Harrell              3269.0             300.0               3000.0
# Eric Moore                      NaN               NaN                  NaN
# Eric Fitzgerald              2175.0              20.0                  NaN
# Gloria Taylor                5394.0               NaN                  NaN
# Betty Levy                     50.0               NaN               2000.0
# Genevieve Brown               300.0             100.0               4000.0
# Rodney Montague                20.0              50.0               2000.0
# David Mcguffee               2175.0              20.0              10000.0
# Gertrude Freer              21747.0               NaN                  1.0
# Abraham Gaytan               5449.0              50.0                  NaN
# Cynthia Curley               2179.0              20.0                  1.0
# Blythe Konowal                100.0               NaN               5000.0
# Kenneth Drayton                50.0               NaN               5000.0
# Ellen Simmons                 117.0               NaN                  NaN
# Sandra Cleare                   NaN               NaN                  NaN
# Christine Newton               20.0              20.0                  1.0
# Michael Mcglothin               NaN               NaN                  NaN
# Anthony Wall                   30.0              20.0               2000.0
# Maurice Morton                 50.0              20.0               2000.0
# Edmond Roach                  100.0              20.0                500.0
# Robyn Davis                    20.0              15.0               2000.0
# Andrew Hookano                  NaN               NaN               2000.0
# Hollis Kellam                  50.0              20.0                  1.0
# Brian Rodney                   50.0               NaN                  NaN
# ...                             ...               ...                  ...
# Christopher Mcanulty         1618.0              20.0                  NaN
# Will Ahmad                     60.0             100.0                  1.0
# Thomas Yanko                   55.0              15.0               2000.0
# Steven Holmes                  65.0              20.0               6600.0
# Helen Lowell                   50.0              20.0                500.0
# Angela Daley                   20.0               NaN                  NaN
# Joan Ferrell                   25.0              10.0               1000.0
# Mark Irvin                   5229.0             100.0               5000.0
# Ann Bostick                  5229.0              25.0               3000.0
# Ricky Young                  5229.0              20.0               3000.0
# Melissa Sodhi                  40.0              20.0                  1.0
# Jill Riordan                 3137.0               NaN                  1.0
# Kelvin Hankins               2602.0              25.0                  NaN
# Mary Houis                     30.0              25.0               4000.0
# Rosie Collins                   NaN               NaN               4000.0
# David Fritcher               2091.0              20.0               2000.0
# Sue Moore                    3137.0              10.0                  NaN
# Renata Brown                 3137.0               NaN               7000.0
# Kathy Adams                    60.0              30.0               1000.0
# Shannon Otsu                  523.0               NaN                  1.0
# Timothy Garner               5906.0              50.0                  1.0
# Vanessa Geiger               3528.0              10.0                  1.0
# Janet Franco                   60.0               NaN               2600.0
# Kenneth Vaccaro                70.0               NaN                  NaN
# Maria Skeesick                 40.0              20.0                  NaN
# Ricky Kocher                  588.0              50.0                  1.0
# Ty Taylor                       NaN               NaN                  NaN
# Marietta Merrigan             588.0               NaN                  NaN
# Shawnee Johnson              5394.0               NaN               2000.0
# Albert Flom                     NaN               NaN                  NaN
#
#                       VL_LMTCHESPECIAL  VL_EMP_FINAN  VL_APLICACAO  \
# name
# Eric Modafferi                     NaN     2306983.0           NaN
# Jay Robinson                    2300.0      799141.0      501828.0
# William Dickhoff                5000.0           NaN           NaN
# Ernesto Jackson                    NaN      477693.0       92427.0
# Jack Barnett                    5000.0     3552662.0       10849.0
# Jamie Hamilton                  2500.0      116493.0        2498.0
# Emelina Harrell                10000.0           NaN           NaN
# Eric Moore                         NaN      580517.0           NaN
# Eric Fitzgerald                 1000.0      901532.0           NaN
# Gloria Taylor                      NaN           NaN     3259284.0
# Betty Levy                         NaN      491688.0      431273.0
# Genevieve Brown                 5000.0     1918123.0     6527374.0
# Rodney Montague                 5000.0      480753.0           NaN
# David Mcguffee                  2000.0      190021.0    15418115.0
# Gertrude Freer                     NaN     1875028.0           NaN
# Abraham Gaytan                     NaN           NaN        2505.0
# Cynthia Curley                     NaN      234315.0           NaN
# Blythe Konowal                 10000.0       95487.0      114641.0
# Kenneth Drayton                 5000.0     6993623.0      235348.0
# Ellen Simmons                  10000.0     3100899.0        2266.0
# Sandra Cleare                  20000.0           NaN           NaN
# Christine Newton                6000.0     2073882.0           NaN
# Michael Mcglothin                  NaN           NaN     1064241.0
# Anthony Wall                    1000.0           NaN        2216.0
# Maurice Morton                  1000.0           NaN        2213.0
# Edmond Roach                    1000.0     1858132.0         358.0
# Robyn Davis                     1000.0           NaN        1029.0
# Andrew Hookano                 10000.0           NaN           NaN
# Hollis Kellam                   1000.0           NaN        2212.0
# Brian Rodney                    1000.0           NaN        5211.0
# ...                                ...           ...           ...
# Christopher Mcanulty               NaN           NaN          43.0
# Will Ahmad                         NaN     2643682.0           NaN
# Thomas Yanko                       NaN      940419.0           NaN
# Steven Holmes                      NaN     1546713.0           NaN
# Helen Lowell                       NaN           NaN           NaN
# Angela Daley                       NaN      804414.0           NaN
# Joan Ferrell                       NaN      153077.0           NaN
# Mark Irvin                         NaN      550176.0           NaN
# Ann Bostick                        NaN           NaN           NaN
# Ricky Young                        NaN           NaN           NaN
# Melissa Sodhi                      NaN     1228097.0        2306.0
# Jill Riordan                       NaN     1325078.0        2057.0
# Kelvin Hankins                     NaN           NaN           NaN
# Mary Houis                         NaN     2000102.0        2313.0
# Rosie Collins                      NaN           NaN     1992589.0
# David Fritcher                     NaN           NaN           NaN
# Sue Moore                          NaN      858608.0         619.0
# Renata Brown                       NaN     1600009.0           NaN
# Kathy Adams                        NaN     1759275.0        2305.0
# Shannon Otsu                       NaN           NaN      511313.0
# Timothy Garner                     NaN      721739.0           NaN
# Vanessa Geiger                     NaN      986152.0        1373.0
# Janet Franco                       NaN           NaN         546.0
# Kenneth Vaccaro                    NaN           NaN           NaN
# Maria Skeesick                     NaN      300331.0         137.0
# Ricky Kocher                       NaN     1032274.0      159471.0
# Ty Taylor                          NaN           NaN           NaN
# Marietta Merrigan                  NaN           NaN           NaN
# Shawnee Johnson                    NaN     1901509.0           NaN
# Albert Flom                        NaN     1558876.0           NaN
#
#                       VL_COTASCAPITAL      ...       VL_RECEB_FOLHA  \
# name                                       ...
# Eric Modafferi                  637.0      ...                  NaN
# Jay Robinson                 309338.0      ...                  NaN
# William Dickhoff             421398.0      ...                  NaN
# Ernesto Jackson              115768.0      ...                  NaN
# Jack Barnett                 549289.0      ...                  NaN
# Jamie Hamilton               159671.0      ...                  NaN
# Emelina Harrell              102944.0      ...                  NaN
# Eric Moore                     2138.0      ...                  NaN
# Eric Fitzgerald               57979.0      ...                  NaN
# Gloria Taylor                140448.0      ...                  NaN
# Betty Levy                   136556.0      ...                  NaN
# Genevieve Brown              286184.0      ...                  NaN
# Rodney Montague               85607.0      ...                  NaN
# David Mcguffee                77393.0      ...                  NaN
# Gertrude Freer               415741.0      ...                  NaN
# Abraham Gaytan               154012.0      ...                  NaN
# Cynthia Curley                47722.0      ...                  NaN
# Blythe Konowal               270806.0      ...                  NaN
# Kenneth Drayton              583097.0      ...                  NaN
# Ellen Simmons                733128.0      ...                  NaN
# Sandra Cleare                647745.0      ...                  NaN
# Christine Newton             229667.0      ...                  NaN
# Michael Mcglothin              5874.0      ...                  NaN
# Anthony Wall                  51881.0      ...                  NaN
# Maurice Morton                82061.0      ...                  NaN
# Edmond Roach                 135254.0      ...                  NaN
# Robyn Davis                   46855.0      ...                  NaN
# Andrew Hookano                40933.0      ...                  NaN
# Hollis Kellam                 79998.0      ...                  NaN
# Brian Rodney                   1100.0      ...                  NaN
# ...                               ...      ...                  ...
# Christopher Mcanulty          32737.0      ...                  NaN
# Will Ahmad                   754895.0      ...                  NaN
# Thomas Yanko                 224194.0      ...                  NaN
# Steven Holmes                176259.0      ...                  NaN
# Helen Lowell                 128503.0      ...                  NaN
# Angela Daley                      1.0      ...                  NaN
# Joan Ferrell                   2976.0      ...                  NaN
# Mark Irvin                    83175.0      ...                  NaN
# Ann Bostick                  228448.0      ...                  NaN
# Ricky Young                   15935.0      ...                  NaN
# Melissa Sodhi                 74185.0      ...                  NaN
# Jill Riordan                   8142.0      ...                  NaN
# Kelvin Hankins                79979.0      ...                  NaN
# Mary Houis                   119735.0      ...                  NaN
# Rosie Collins                  6333.0      ...                  NaN
# David Fritcher                90326.0      ...                  NaN
# Sue Moore                     71596.0      ...                  NaN
# Renata Brown                  72335.0      ...                  NaN
# Kathy Adams                  104735.0      ...                  NaN
# Shannon Otsu                  14166.0      ...                  NaN
# Timothy Garner               177569.0      ...                  NaN
# Vanessa Geiger               167135.0      ...                  NaN
# Janet Franco                 482228.0      ...                  NaN
# Kenneth Vaccaro               27199.0      ...                  NaN
# Maria Skeesick                14495.0      ...                  NaN
# Ricky Kocher                 318064.0      ...                  NaN
# Ty Taylor                    111684.0      ...                  NaN
# Marietta Merrigan           1297637.0      ...                  NaN
# Shawnee Johnson              354655.0      ...                  NaN
# Albert Flom                       1.0      ...                  NaN
#
#                       VL_LMTTRANSACAO  VL_LMTDESCTTIT  VL_LMTDESCTCHEQ  \
# name
# Eric Modafferi                    NaN             NaN           5000.0
# Jay Robinson                  11000.0             NaN              NaN
# William Dickhoff              55000.0             NaN              NaN
# Ernesto Jackson               18000.0             NaN              NaN
# Jack Barnett                  90000.0             NaN              NaN
# Jamie Hamilton                26000.0             NaN              NaN
# Emelina Harrell               12000.0             NaN              NaN
# Eric Moore                        NaN             NaN              NaN
# Eric Fitzgerald                   NaN             NaN              NaN
# Gloria Taylor                 30000.0             NaN              NaN
# Betty Levy                    90000.0             NaN              NaN
# Genevieve Brown              150000.0         25000.0              NaN
# Rodney Montague               15000.0             NaN           3000.0
# David Mcguffee               300000.0         15000.0              NaN
# Gertrude Freer                28000.0             NaN              NaN
# Abraham Gaytan               175000.0             NaN              NaN
# Cynthia Curley                 6000.0             NaN              NaN
# Blythe Konowal                45000.0             NaN          30000.0
# Kenneth Drayton               15000.0             NaN              NaN
# Ellen Simmons                 40000.0             NaN              NaN
# Sandra Cleare                  3000.0             NaN              NaN
# Christine Newton              15000.0             NaN           5000.0
# Michael Mcglothin                 NaN             NaN              NaN
# Anthony Wall                  15000.0             NaN              NaN
# Maurice Morton                30000.0             NaN              NaN
# Edmond Roach                  15000.0             NaN           3500.0
# Robyn Davis                   60000.0             NaN          14000.0
# Andrew Hookano               150000.0             NaN              NaN
# Hollis Kellam                108000.0             NaN              NaN
# Brian Rodney                  30000.0         10000.0              NaN
# ...                               ...             ...              ...
# Christopher Mcanulty           9000.0             NaN              NaN
# Will Ahmad                   240000.0        150000.0              NaN
# Thomas Yanko                 150000.0         40000.0          40000.0
# Steven Holmes                 12000.0             NaN              NaN
# Helen Lowell                   9000.0             NaN              NaN
# Angela Daley                      NaN             NaN              NaN
# Joan Ferrell                   1000.0             NaN              NaN
# Mark Irvin                     6000.0             NaN           7000.0
# Ann Bostick                   30000.0             NaN           8000.0
# Ricky Young                   12000.0             NaN              NaN
# Melissa Sodhi                 30000.0             NaN              NaN
# Jill Riordan                  30000.0             NaN              NaN
# Kelvin Hankins                    NaN             NaN              NaN
# Mary Houis                    60000.0             NaN          25000.0
# Rosie Collins                300000.0             NaN              NaN
# David Fritcher                 6000.0             NaN              NaN
# Sue Moore                     15000.0             NaN              NaN
# Renata Brown                  30000.0             NaN              NaN
# Kathy Adams                   15000.0             NaN              NaN
# Shannon Otsu                  24000.0             NaN              NaN
# Timothy Garner                 3000.0             NaN              NaN
# Vanessa Geiger                 7500.0             NaN           2000.0
# Janet Franco                  35000.0             NaN           5000.0
# Kenneth Vaccaro                   NaN             NaN              NaN
# Maria Skeesick                30000.0             NaN              NaN
# Ricky Kocher                  15000.0             NaN              NaN
# Ty Taylor                         NaN             NaN              NaN
# Marietta Merrigan            150000.0             NaN              NaN
# Shawnee Johnson               25000.0         35000.0           5000.0
# Albert Flom                       NaN             NaN              NaN
#
#                       VL_COBBANC  VL_SEG_VIDA  VL_SEG_RES  VL_SEG_AUTO  \
# name
# Eric Modafferi               NaN          NaN         NaN          NaN
# Jay Robinson                 NaN          NaN         NaN          NaN
# William Dickhoff             NaN          NaN         NaN          NaN
# Ernesto Jackson        1168221.0          NaN         NaN          NaN
# Jack Barnett                 NaN          NaN         NaN          NaN
# Jamie Hamilton               NaN          NaN         NaN          NaN
# Emelina Harrell        3250521.0          NaN         NaN          NaN
# Eric Moore                   NaN          NaN         NaN          NaN
# Eric Fitzgerald              NaN          NaN         NaN          NaN
# Gloria Taylor          1639708.0          NaN         NaN          NaN
# Betty Levy                 385.0          NaN         NaN          NaN
# Genevieve Brown         932061.0          NaN         NaN          NaN
# Rodney Montague              NaN          NaN         NaN          NaN
# David Mcguffee         2098797.0          NaN         NaN          NaN
# Gertrude Freer               NaN          NaN         NaN          NaN
# Abraham Gaytan               NaN          NaN         NaN          NaN
# Cynthia Curley               NaN          NaN         NaN          NaN
# Blythe Konowal               NaN          NaN         NaN          NaN
# Kenneth Drayton              NaN          NaN         NaN          NaN
# Ellen Simmons                NaN          NaN         NaN          NaN
# Sandra Cleare         12829969.0          NaN         NaN          NaN
# Christine Newton             NaN          NaN         NaN          NaN
# Michael Mcglothin            NaN          NaN         NaN          NaN
# Anthony Wall                 NaN          NaN         NaN          NaN
# Maurice Morton               NaN          NaN         NaN          NaN
# Edmond Roach                 NaN          NaN         NaN          NaN
# Robyn Davis               2880.0          NaN         NaN          NaN
# Andrew Hookano          461691.0          NaN         NaN          NaN
# Hollis Kellam          1305873.0          NaN         NaN          NaN
# Brian Rodney            378979.0          NaN         NaN          NaN
# ...                          ...          ...         ...          ...
# Christopher Mcanulty         NaN          NaN         NaN          NaN
# Will Ahmad                   NaN          NaN         NaN          NaN
# Thomas Yanko           5796016.0          NaN         NaN          NaN
# Steven Holmes                NaN          NaN         NaN          NaN
# Helen Lowell                 NaN          NaN         NaN          NaN
# Angela Daley                 NaN          NaN         NaN          NaN
# Joan Ferrell                 NaN          NaN         NaN          NaN
# Mark Irvin                   NaN          NaN         NaN          NaN
# Ann Bostick               2736.0          NaN         NaN          NaN
# Ricky Young                  NaN          NaN         NaN          NaN
# Melissa Sodhi             5541.0          NaN         NaN          NaN
# Jill Riordan            770686.0          NaN         NaN          NaN
# Kelvin Hankins               NaN          NaN         NaN          NaN
# Mary Houis                   NaN          NaN         NaN          NaN
# Rosie Collins                NaN          NaN         NaN          NaN
# David Fritcher               NaN          NaN         NaN          NaN
# Sue Moore                    NaN          NaN         NaN          NaN
# Renata Brown           1045972.0          NaN         NaN          NaN
# Kathy Adams                  NaN          NaN         NaN          NaN
# Shannon Otsu                 NaN          NaN         NaN          NaN
# Timothy Garner               NaN          NaN         NaN          NaN
# Vanessa Geiger               NaN          NaN         NaN          NaN
# Janet Franco                 NaN          NaN         NaN          NaN
# Kenneth Vaccaro              NaN          NaN         NaN          NaN
# Maria Skeesick            6965.0          NaN         NaN          NaN
# Ricky Kocher           2765833.0          NaN         NaN          NaN
# Ty Taylor                    NaN          NaN         NaN          NaN
# Marietta Merrigan            NaN          NaN         NaN          NaN
# Shawnee Johnson        2407818.0          NaN         NaN          NaN
# Albert Flom                  NaN          NaN         NaN          NaN
#
#                       VL_CONV_FOLHA_PAGTO  VL_DEBITOAUT
# name
# Eric Modafferi                        NaN           NaN
# Jay Robinson                          NaN           NaN
# William Dickhoff                      NaN           NaN
# Ernesto Jackson                       NaN           NaN
# Jack Barnett                          NaN           NaN
# Jamie Hamilton                        NaN           NaN
# Emelina Harrell                       NaN           NaN
# Eric Moore                            NaN           NaN
# Eric Fitzgerald                       NaN           NaN
# Gloria Taylor                         NaN           2.0
# Betty Levy                            NaN           NaN
# Genevieve Brown                       NaN           1.0
# Rodney Montague                       NaN           NaN
# David Mcguffee                        NaN           NaN
# Gertrude Freer                        NaN           NaN
# Abraham Gaytan                        NaN           NaN
# Cynthia Curley                        NaN           NaN
# Blythe Konowal                        NaN           NaN
# Kenneth Drayton                       NaN           NaN
# Ellen Simmons                         NaN           1.0
# Sandra Cleare                         NaN           1.0
# Christine Newton                      NaN           NaN
# Michael Mcglothin                     NaN           NaN
# Anthony Wall                          NaN           NaN
# Maurice Morton                        NaN           NaN
# Edmond Roach                          NaN           NaN
# Robyn Davis                           NaN           NaN
# Andrew Hookano                        NaN           2.0
# Hollis Kellam                         NaN           1.0
# Brian Rodney                          NaN           NaN
# ...                                   ...           ...
# Christopher Mcanulty                  NaN           NaN
# Will Ahmad                            NaN          17.0
# Thomas Yanko                          NaN          23.0
# Steven Holmes                         NaN           1.0
# Helen Lowell                          NaN           2.0
# Angela Daley                          NaN           NaN
# Joan Ferrell                          NaN           NaN
# Mark Irvin                            NaN           NaN
# Ann Bostick                           NaN           1.0
# Ricky Young                           NaN           NaN
# Melissa Sodhi                         NaN           NaN
# Jill Riordan                          NaN           NaN
# Kelvin Hankins                        NaN           NaN
# Mary Houis                            NaN           1.0
# Rosie Collins                         NaN           NaN
# David Fritcher                        NaN           NaN
# Sue Moore                             NaN           1.0
# Renata Brown                          NaN           NaN
# Kathy Adams                           NaN           3.0
# Shannon Otsu                          NaN           NaN
# Timothy Garner                        NaN           NaN
# Vanessa Geiger                        NaN           NaN
# Janet Franco                          NaN           NaN
# Kenneth Vaccaro                       NaN           NaN
# Maria Skeesick                        NaN           NaN
# Ricky Kocher                    1014397.0           2.0
# Ty Taylor                             NaN           NaN
# Marietta Merrigan                     NaN           1.0
# Shawnee Johnson                       NaN           NaN
# Albert Flom                           NaN           NaN
#
# [61777 rows x 22 columns]

# %% [markdown]
# Sparse, but how sparse?

# %%
data.to_sparse(fill_value=np.NaN).density
# Out:
# 0.35969844617075786

# %% [markdown]
# Not that sparse, actually, but the columns variance is huge. Since we'll normalize and scale the data, this should not be a problem, but I've never done this with this kind of dataset, so let's hope for the best
#
# Now we'll import our model and get on with it
#
# Quick Q.A. on the number of features below:
# - **How many features?** dunno
# - **How do you choose the number of featues?** Grid search
# - **Did I do it?** No
# - **More features == better?** Not necessarily. A lot of features increase variance and model complexity, reducing bias  and overfitting your model. Too little features decrease your model complexity, making it too biased and useless as a general model

# %%
model = SVDRecommender(n_features=14)

model.fit(data)
# Out:
# SVDRecommender. features: 14, method:default

# %%
test_users = ['Eric Modafferi', 'Tina Roberts']
test_items = ['VL_POUPPROG', 'VL_LMTCARTAOCREDITO']


# recommends 3 undiscovered items per each user
print("\nUser recommendations", model.recommend(test_users, N=3))

# Recommend 3 users to buy certain items and show the prices
print("\nItem recommendations", model.recommend(test_items, content='item', N=3, values=True))

# outputs 5 most similar items to VL_DOMICBANC
# What makes a similar item?
print("\nMost similar", model.topN_similar(x='VL_DOMICBANC', N=3, column='item'))
# Out:
# User recommendations [['VL_COBBANC', 'VL_CONV_FOLHA_PAGTO', 'VL_APLICACAO'], ['VL_COBBANC', 'VL_CONV_FOLHA_PAGTO', 'VL_APLICACAO']]
#
# Item recommendations [[('Debra Propst', 76895.469567145788), ('James Payne', 76496.779612962768), ('Dorothy Powell', 76406.044309660851)], [('Dorothy Lujan', 54753.889388363728), ('Kandy Ford', 48631.013085703984), ('Heather Coleman', 41067.195125058832)]]
#
# Most similar [('VL_LMTCARTAOCREDITO', 13694.805049625806), ('VL_PLANOCOTAS', 13695.272958898822), ('VL_DEBITOAUT', 13695.757727444545)]

# %% [markdown]
# As you can see, Eric's recommendations are really close to Tina's. Let's see if they come as similar

# %%
model.topN_similar(x='Eric Modafferi', N=5, column='user')
# Out:
# [('Ashlee Irvin', 2.629715661965943),
#  ('Kimberly Colin', 3.0407430086878495),
#  ('Stacey Byrd', 3.0431025129539995),
#  ('Dawn Mason', 3.5870264131794696),
#  ('Gloria Cardoso', 3.8856505688515326)]

# %% [markdown]
# Yep, there she is, third place.
#
# Note that the recommendation does not correlate completely with the similarity. That is just a coincidence
#
# Let's take a look at their vectors

# %%
data[(data.index == 'Eric Modafferi') | (data.index == 'Tina Roberts')]
# Out:
#                 VL_RENDA_FATANUAL  VL_RENDA_PFPJ  VL_DOMICBANC  VL_PLANOCOTAS  \
# name
# Eric Modafferi            17450.0         2980.0           NaN           10.0
# Tina Roberts              15000.0         4530.0           NaN          150.0
#
#                 VL_PLANOPOUPPROG  VL_LMTCARTAOCREDITO  VL_LMTCHESPECIAL  \
# name
# Eric Modafferi               NaN                  NaN               NaN
# Tina Roberts                 NaN                  1.0               NaN
#
#                 VL_EMP_FINAN  VL_APLICACAO  VL_COTASCAPITAL      ...       \
# name                                                             ...
# Eric Modafferi     2306983.0           NaN            637.0      ...
# Tina Roberts       4423174.0           NaN         440921.0      ...
#
#                 VL_RECEB_FOLHA  VL_LMTTRANSACAO  VL_LMTDESCTTIT  \
# name
# Eric Modafferi             NaN              NaN             NaN
# Tina Roberts               NaN            300.0             NaN
#
#                 VL_LMTDESCTCHEQ  VL_COBBANC  VL_SEG_VIDA  VL_SEG_RES  \
# name
# Eric Modafferi           5000.0         NaN          NaN         NaN
# Tina Roberts                NaN         NaN          NaN         NaN
#
#                 VL_SEG_AUTO  VL_CONV_FOLHA_PAGTO  VL_DEBITOAUT
# name
# Eric Modafferi          NaN                  NaN           NaN
# Tina Roberts            NaN                  NaN           2.0
#
# [2 rows x 22 columns]

# %% [markdown]
# We can also predict values for any client

# %%
query = [['Eric Modafferi', 'VL_RENDA_PFPJ'], ['Eric Modafferi', 'VL_DOMICBANC']]
query = pd.DataFrame(query)

query
# Out:
#                 0              1
# 0  Eric Modafferi  VL_RENDA_PFPJ
# 1  Eric Modafferi   VL_DOMICBANC

# %% [markdown]
# Our client already has VL_RENDA_PFPJ and its value is 2980.0, so we hope that our prediction is close to that

# %%
model.predict(query)
# Out:
# [2979.9996505621821, 531150.32808172004]

# %% [markdown]
# Indeed, 2979.99 is pretty much 2980. Not too shaby
#
# Finally, let's predict the values of every user for the product VL_LMTCARTAOCREDITO, VL_LMTCHESPECIAL

# %%
new = pd.DataFrame()
new['user'] = data.index
new['item'] = ['VL_LMTCARTAOCREDITO'] * len(data)
new['VL_LMTCARTAOCREDITO'] = model.predict(new)
new_2 = pd.DataFrame()
new_2['user'] = data.index
new_2['item'] = ['VL_LMTCHESPECIAL'] * len(data)
new_2['pred'] = model.predict(new_2)
new['VL_LMTCHESPECIAL'] = new_2['pred']

new.head(15)
# Out:
#                 user                 item  VL_LMTCARTAOCREDITO  \
# 0     Eric Modafferi  VL_LMTCARTAOCREDITO          2121.508846
# 1       Jay Robinson  VL_LMTCARTAOCREDITO          2504.177017
# 2   William Dickhoff  VL_LMTCARTAOCREDITO          2837.417817
# 3    Ernesto Jackson  VL_LMTCARTAOCREDITO          2553.567414
# 4       Jack Barnett  VL_LMTCARTAOCREDITO          2919.957317
# 5     Jamie Hamilton  VL_LMTCARTAOCREDITO          2437.967964
# 6    Emelina Harrell  VL_LMTCARTAOCREDITO          2893.186350
# 7         Eric Moore  VL_LMTCARTAOCREDITO          2553.721586
# 8    Eric Fitzgerald  VL_LMTCARTAOCREDITO          2306.415776
# 9      Gloria Taylor  VL_LMTCARTAOCREDITO          2703.245454
# 10        Betty Levy  VL_LMTCARTAOCREDITO          2632.781029
# 11   Genevieve Brown  VL_LMTCARTAOCREDITO          2731.606910
# 12   Rodney Montague  VL_LMTCARTAOCREDITO          1986.531786
# 13    David Mcguffee  VL_LMTCARTAOCREDITO          2428.254303
# 14    Gertrude Freer  VL_LMTCARTAOCREDITO          2914.999465
#
#     VL_LMTCHESPECIAL
# 0        6267.639448
# 1        2160.929938
# 2        4988.817359
# 3        6201.736091
# 4        5099.407992
# 5        2503.849817
# 6       10018.479394
# 7        6251.965182
# 8        1032.465560
# 9        6269.026256
# 10       6197.711876
# 11       5060.369576
# 12       4995.462220
# 13       2404.551607
# 14       6213.372834

# %%
(new.set_index(names['name'])['VL_LMTCHESPECIAL'] - data['VL_LMTCHESPECIAL'].fillna(0))[~pd.isnull(data['VL_LMTCHESPECIAL'])].describe()
# Out:
# count     5179.000000
# mean        11.844479
# std        357.871128
# min      -3285.705701
# 25%       -115.268543
# 50%        -25.487257
# 75%         26.185173
# max      12633.725639
# Name: VL_LMTCHESPECIAL, dtype: float64

# %%
(new.set_index(names['name'])['VL_LMTCARTAOCREDITO'] - data['VL_LMTCARTAOCREDITO'].fillna(0))[~pd.isnull(data['VL_LMTCARTAOCREDITO'])].describe()
# Out:
# count    4.080000e+04
# mean    -4.415780e+01
# std      9.852801e+03
# min     -1.291017e+06
# 25%     -1.617784e+02
# 50%      1.548923e+03
# 75%      2.575811e+03
# max      6.042688e+04
# Name: VL_LMTCARTAOCREDITO, dtype: float64
